# %%
import scanpy as sc
import pandas as pd
import numpy as np

import sys
sys.path.append("../")
from teju_utils.stats_metrics import *
from teju_utils.plots import *

# %%
import glob

# %%
def extract_names(f):
    if "results" in f:
        split=f.split("/results/")[1].split("/")
        
        stage='1' if split[2] == 'stage1' else '2'
        # print(split, stage)
        dict = {
            "tag": "fake",
            "fake_path": f,
            "dataset":split[0],
            "cross_val":split[1].strip("CrossVal_"),
            "knowledge_base":split[2].strip("KB_"),
            "stage":stage,
            "freq":split[3] if stage == '2' else None,
            "method":split[4] if stage == '2' else None,
            "seed":split[5].strip("Seed") if stage == '2' else None,
            "TF":split[6].strip("TF") if stage == '2' else None,
            "simulated":split[8] if stage == '2' else split[4]
        }
    else:
        dict= {}
    return dict

# %%
PROJECT_DIR="/p/project1/hai_steerllms/GRouNdGAN/"
df=[]

for dataset in ["PBMC", "PBMC_CTL", "BoneMarrow"]: 
# for dataset in ["LinearUniform"]:
    for cross_val in ["CrossVal_1000", "CrossVal_2000"]:
        files=glob.glob(f'{PROJECT_DIR}/results/{dataset}/{cross_val}/**/*.h5ad', recursive=True)
        for f in files:
            # print(f)
            dict=extract_names(f)
            # print(dict)
            if dataset=='PBMC':
                dict['train_path']=f"{PROJECT_DIR}/data/processed/PBMC/{cross_val}/PBMC68k_train.h5ad"
                dict['test_path']=f'{PROJECT_DIR}/data/processed/PBMC/{cross_val}/PBMC68k_test.h5ad'
                dict['valid_path']=f'{PROJECT_DIR}/data/processed/PBMC/{cross_val}/PBMC68k_validation.h5ad'
            elif dataset == 'PBMC_CTL':
                dict['train_path']=f"{PROJECT_DIR}/data/processed/PBMC_CTL/{cross_val}/PBMC_CTL20k_train.h5ad"
                dict['test_path']=f'{PROJECT_DIR}/data/processed/PBMC_CTL/{cross_val}/PBMC_CTL20k_test.h5ad'
                dict['valid_path']=f'{PROJECT_DIR}/data/processed/PBMC_CTL/{cross_val}/PBMC_CTL20k_validation.h5ad'
            elif dataset == 'BoneMarrow':
                dict['train_path']=f"{PROJECT_DIR}/data/processed/BoneMarrow/{cross_val}/BoneMarrow2k_train.h5ad"
                dict['test_path']=f'{PROJECT_DIR}/data/processed/BoneMarrow/{cross_val}/BoneMarrow2k_test.h5ad'
                dict['valid_path']=f'{PROJECT_DIR}/data/processed/BoneMarrow/{cross_val}/BoneMarrow2k_validation.h5ad'
            elif dataset == 'LinearUniform':
                dict['train_path']=f"{PROJECT_DIR}/data/processed/LinearUniform/{cross_val}/LinearUniform5k_train.h5ad"
                dict['test_path']=f'{PROJECT_DIR}/data/processed/LinearUniform/{cross_val}/LinearUniform5k_test.h5ad'
                dict['valid_path']=f'{PROJECT_DIR}/data/processed/LinearUniform/{cross_val}/LinearUniform5k_validation.h5ad'
            
            df.append(dict)

df=pd.DataFrame(df)

# %%
df.stage.unique
# Out:
# <bound method Series.unique of 0      2
# 1      2
# 2      2
# 3      2
# 4      2
#       ..
# 465    2
# 466    2
# 467    2
# 468    2
# 469    2
# Name: stage, Length: 470, dtype: object>

# %%
df=df.query("simulated !='simulated_trainsize.h5ad'")

# %%
# df=df.query("cross_val=='1000'")

# %%
df.head(6)
# Out:
#     tag                                          fake_path dataset cross_val  \
# 0  fake  /p/project1/hai_steerllms/GRouNdGAN//results/P...    PBMC      1000
# 1  fake  /p/project1/hai_steerllms/GRouNdGAN//results/P...    PBMC      1000
# 2  fake  /p/project1/hai_steerllms/GRouNdGAN//results/P...    PBMC      1000
# 3  fake  /p/project1/hai_steerllms/GRouNdGAN//results/P...    PBMC      1000
# 5  fake  /p/project1/hai_steerllms/GRouNdGAN//results/P...    PBMC      1000
# 6  fake  /p/project1/hai_steerllms/GRouNdGAN//results/P...    PBMC      1000
#
#   knowledge_base stage       freq  method seed  TF         simulated  \
# 0         Random     2  freq_None  Random    1  10  simulated_3.h5ad
# 1         Random     2  freq_None  Random    1  10  simulated_2.h5ad
# 2         Random     2  freq_None  Random    1  10  simulated_1.h5ad
# 3         Random     2  freq_None  Random    1  10  simulated_0.h5ad
# 5        GPT-old     2     freq_1   GRNB2    1  10  simulated_3.h5ad
# 6        GPT-old     2     freq_1   GRNB2    1  10  simulated_2.h5ad
#
#                                           train_path  \
# 0  /p/project1/hai_steerllms/GRouNdGAN//data/proc...
# 1  /p/project1/hai_steerllms/GRouNdGAN//data/proc...
# 2  /p/project1/hai_steerllms/GRouNdGAN//data/proc...
# 3  /p/project1/hai_steerllms/GRouNdGAN//data/proc...
# 5  /p/project1/hai_steerllms/GRouNdGAN//data/proc...
# 6  /p/project1/hai_steerllms/GRouNdGAN//data/proc...
#
#                                            test_path  \
# 0  /p/project1/hai_steerllms/GRouNdGAN//data/proc...
# 1  /p/project1/hai_steerllms/GRouNdGAN//data/proc...
# 2  /p/project1/hai_steerllms/GRouNdGAN//data/proc...
# 3  /p/project1/hai_steerllms/GRouNdGAN//data/proc...
# 5  /p/project1/hai_steerllms/GRouNdGAN//data/proc...
# 6  /p/project1/hai_steerllms/GRouNdGAN//data/proc...
#
#                                           valid_path
# 0  /p/project1/hai_steerllms/GRouNdGAN//data/proc...
# 1  /p/project1/hai_steerllms/GRouNdGAN//data/proc...
# 2  /p/project1/hai_steerllms/GRouNdGAN//data/proc...
# 3  /p/project1/hai_steerllms/GRouNdGAN//data/proc...
# 5  /p/project1/hai_steerllms/GRouNdGAN//data/proc...
# 6  /p/project1/hai_steerllms/GRouNdGAN//data/proc...

# %%
# import scanpy as sc

# %%
from teju_utils.stats_metrics import *

# %%
df_partial=df.query("stage=='1'")
df_partial=df_partial[~df_partial.duplicated(subset=['cross_val','train_path','test_path'])]
df_partial
# Out:
#       tag                                          fake_path     dataset  \
# 45   fake  /p/project1/hai_steerllms/GRouNdGAN//results/P...        PBMC
# 165  fake  /p/project1/hai_steerllms/GRouNdGAN//results/P...        PBMC
# 250  fake  /p/project1/hai_steerllms/GRouNdGAN//results/P...    PBMC_CTL
# 310  fake  /p/project1/hai_steerllms/GRouNdGAN//results/P...    PBMC_CTL
# 370  fake  /p/project1/hai_steerllms/GRouNdGAN//results/B...  BoneMarrow
# 430  fake  /p/project1/hai_steerllms/GRouNdGAN//results/B...  BoneMarrow
#
#     cross_val knowledge_base stage  freq method  seed    TF         simulated  \
# 45       1000         stage1     1  None   None  None  None  simulated_3.h5ad
# 165      2000         stage1     1  None   None  None  None  simulated_3.h5ad
# 250      1000         stage1     1  None   None  None  None  simulated_3.h5ad
# 310      2000         stage1     1  None   None  None  None  simulated_3.h5ad
# 370      1000         stage1     1  None   None  None  None  simulated_3.h5ad
# 430      2000         stage1     1  None   None  None  None  simulated_3.h5ad
#
#                                             train_path  \
# 45   /p/project1/hai_steerllms/GRouNdGAN//data/proc...
# 165  /p/project1/hai_steerllms/GRouNdGAN//data/proc...
# 250  /p/project1/hai_steerllms/GRouNdGAN//data/proc...
# 310  /p/project1/hai_steerllms/GRouNdGAN//data/proc...
# 370  /p/project1/hai_steerllms/GRouNdGAN//data/proc...
# 430  /p/project1/hai_steerllms/GRouNdGAN//data/proc...
#
#                                              test_path  \
# 45   /p/project1/hai_steerllms/GRouNdGAN//data/proc...
# 165  /p/project1/hai_steerllms/GRouNdGAN//data/proc...
# 250  /p/project1/hai_steerllms/GRouNdGAN//data/proc...
# 310  /p/project1/hai_steerllms/GRouNdGAN//data/proc...
# 370  /p/project1/hai_steerllms/GRouNdGAN//data/proc...
# 430  /p/project1/hai_steerllms/GRouNdGAN//data/proc...
#
#                                             valid_path
# 45   /p/project1/hai_steerllms/GRouNdGAN//data/proc...
# 165  /p/project1/hai_steerllms/GRouNdGAN//data/proc...
# 250  /p/project1/hai_steerllms/GRouNdGAN//data/proc...
# 310  /p/project1/hai_steerllms/GRouNdGAN//data/proc...
# 370  /p/project1/hai_steerllms/GRouNdGAN//data/proc...
# 430  /p/project1/hai_steerllms/GRouNdGAN//data/proc...

# %%
metric='perc_zeros'
df[metric+'_fake'] = df['fake_path'].apply(lambda x: calculate_perc_zeros(x))
df[metric+'_train'] = df_partial['train_path'].apply(lambda x: calculate_perc_zeros(x))
df[metric+'_test'] = df_partial['test_path'].apply(lambda x: calculate_perc_zeros(x))
df[metric+'_valid'] = df_partial['valid_path'].apply(lambda x: calculate_perc_zeros(x))

# %%
metric='cosine_distance'
df[metric+'_fake_train'] = df.apply(lambda x: compute_cosine(x['train_path'], x['fake_path']), axis=1)
df[metric+'_fake_test'] = df.apply(lambda x: compute_cosine(x['test_path'], x['fake_path']), axis=1)
df_partial[metric+'_train_test'] = df_partial.apply(lambda x: compute_cosine(x['test_path'], x['train_path']), axis=1)

# %%
df=df.fillna("None")
columns=['cosine_distance_fake_test']
df.groupby(['dataset', 'stage', 'knowledge_base', "freq", "method","cross_val"]).agg(['mean', 'std'])[columns]
# Out:
#                                                            cosine_distance_fake_test  \
#                                                                                 mean
# dataset    stage knowledge_base freq      method cross_val
# BoneMarrow 1     stage1         None      None   1000                       0.002594
#                                                  2000                       0.003811
#            2     GPT            freq_1    GPT4   1000                       0.001805
#                                                  2000                       0.002540
#                                           GRNB2  1000                       0.001995
# ...                                                                              ...
# PBMC_CTL   2     Sapien         freq_None GPT4   2000                       0.005016
#                                           GRNB2  1000                       0.000290
#                                                  2000                       0.000218
#                                           Random 1000                       0.000313
#                                                  2000                       0.000222
#
#
#                                                                  std
# dataset    stage knowledge_base freq      method cross_val
# BoneMarrow 1     stage1         None      None   1000       0.000437
#                                                  2000       0.001377
#            2     GPT            freq_1    GPT4   1000       0.000379
#                                                  2000       0.000292
#                                           GRNB2  1000       0.000161
# ...                                                              ...
# PBMC_CTL   2     Sapien         freq_None GPT4   2000       0.000027
#                                           GRNB2  1000       0.000025
#                                                  2000       0.000012
#                                           Random 1000       0.000013
#                                                  2000       0.000019
#
# [94 rows x 2 columns]

# %%
df=df.fillna("None")
columns=['cosine_distance_fake_test']
df.groupby(['dataset', 'stage', 'knowledge_base', "freq", "method"]).agg(['mean', 'std'])[columns].round(5)
# Out:
#                                                    cosine_distance_fake_test  \
#                                                                         mean
# dataset    stage knowledge_base freq        method
# BoneMarrow 1     stage1         None        None                     0.00320
#            2     GPT            freq_1      GPT4                     0.00217
#                                             GRNB2                    0.00193
#                                             Random                   0.00297
#                                 freq_2      GPT4                     0.00247
#                                             GRNB2                    0.00252
#                                             Random                   0.00230
#                  Llama          freq_2      GRNB2                    0.00195
#                  Random         freq_None   Random                   0.00206
#                  Sapien         freq_None   GPT4                     0.00238
#                                             GRNB2                    0.00190
#                                             Random                   0.00219
# PBMC       1     stage1         None        None                     0.00036
#            2     GPT            freq_1      GPT4                     0.00026
#                                             GRNB2                    0.00023
#                                             Random                   0.00026
#                                 freq_2      GPT4                     0.02328
#                                             GRNB2                    0.02270
#                                             Random                   0.00045
#                  GPT-old        freq_1      GPT4                     0.00026
#                                             GRNB2                    0.00023
#                                 freq_2      GPT4                     0.43602
#                                             GRNB2                    0.02273
#                  Llama          freq_1      GPT4                     0.00029
#                                             GRNB2                    0.00022
#                                             Random                   0.00035
#                                 freq_2      GPT4                     0.00040
#                                             GRNB2                    0.00242
#                                             Random                   0.00064
#                                 no_kb_gpt   GRNB2                    0.00032
#                                 no_kb_human GRNB2                    0.00034
#                  Random         freq_None   Random                   0.00132
#                  Sapien         freq_None   GPT4                     0.00024
#                                             GRNB2                    0.00047
#                                             Llama                    0.00114
#                                             Random                   0.00045
# PBMC_CTL   1     stage1         None        None                     0.00023
#            2     GPT            freq_1      GPT4                     0.00028
#                                             GRNB2                    0.00020
#                                             Random                   0.00022
#                                 freq_2      GPT4                     0.00031
#                                             GRNB2                    0.00025
#                                             Random                   0.00030
#                  Llama          freq_2      GRNB2                    0.00012
#                  Random         freq_None   Random                   0.00016
#                  Sapien         freq_None   GPT4                     0.00265
#                                             GRNB2                    0.00025
#                                             Random                   0.00027
#
#
#                                                         std
# dataset    stage knowledge_base freq        method
# BoneMarrow 1     stage1         None        None    0.00115
#            2     GPT            freq_1      GPT4    0.00050
#                                             GRNB2   0.00023
#                                             Random  0.00080
#                                 freq_2      GPT4    0.00097
#                                             GRNB2   0.00096
#                                             Random  0.00043
#                  Llama          freq_2      GRNB2   0.00020
#                  Random         freq_None   Random  0.00034
#                  Sapien         freq_None   GPT4    0.00052
#                                             GRNB2   0.00023
#                                             Random  0.00030
# PBMC       1     stage1         None        None    0.00009
#            2     GPT            freq_1      GPT4    0.00009
#                                             GRNB2   0.00008
#                                             Random  0.00011
#                                 freq_2      GPT4    0.02451
#                                             GRNB2   0.02401
#                                             Random  0.00009
#                  GPT-old        freq_1      GPT4    0.00009
#                                             GRNB2   0.00008
#                                 freq_2      GPT4    0.46581
#                                             GRNB2   0.02404
#                  Llama          freq_1      GPT4    0.00005
#                                             GRNB2   0.00006
#                                             Random  0.00009
#                                 freq_2      GPT4    0.00008
#                                             GRNB2   0.00221
#                                             Random  0.00032
#                                 no_kb_gpt   GRNB2   0.00008
#                                 no_kb_human GRNB2   0.00023
#                  Random         freq_None   Random  0.00101
#                  Sapien         freq_None   GPT4    0.00004
#                                             GRNB2   0.00021
#                                             Llama   0.00048
#                                             Random  0.00013
# PBMC_CTL   1     stage1         None        None    0.00003
#            2     GPT            freq_1      GPT4    0.00009
#                                             GRNB2   0.00004
#                                             Random  0.00005
#                                 freq_2      GPT4    0.00007
#                                             GRNB2   0.00004
#                                             Random  0.00006
#                  Llama          freq_2      GRNB2   0.00002
#                  Random         freq_None   Random  0.00002
#                  Sapien         freq_None   GPT4    0.00253
#                                             GRNB2   0.00004
#                                             Random  0.00005

# %%
df_partial=df_partial.fillna("None")
columns=['cosine_distance_train_test']
df_partial.groupby(['dataset', 'stage', 'knowledge_base', "freq", "method","cross_val"]).agg(['mean', 'std'])[columns]
# Out:
#                                                       cosine_distance_train_test  \
#                                                                             mean
# dataset    stage knowledge_base freq method cross_val
# BoneMarrow 1     stage1         None None   1000                        0.001927
#                                             2000                        0.002179
# PBMC       1     stage1         None None   1000                        0.000230
#                                             2000                        0.000349
# PBMC_CTL   1     stage1         None None   1000                        0.000234
#                                             2000                        0.000161
#
#
#                                                       std
# dataset    stage knowledge_base freq method cross_val
# BoneMarrow 1     stage1         None None   1000      NaN
#                                             2000      NaN
# PBMC       1     stage1         None None   1000      NaN
#                                             2000      NaN
# PBMC_CTL   1     stage1         None None   1000      NaN
#                                             2000      NaN

# %%
df_partial=df_partial.fillna("None")
columns=['cosine_distance_train_test']
df_partial.groupby(['dataset', 'stage', 'knowledge_base', "freq", "method"]).agg(['mean', 'std'])[columns].round(5)
# Out:
#                                             cosine_distance_train_test  \
#                                                                   mean
# dataset    stage knowledge_base freq method
# BoneMarrow 1     stage1         None None                      0.00205
# PBMC       1     stage1         None None                      0.00029
# PBMC_CTL   1     stage1         None None                      0.00020
#
#
#                                                  std
# dataset    stage knowledge_base freq method
# BoneMarrow 1     stage1         None None    0.00018
# PBMC       1     stage1         None None    0.00008
# PBMC_CTL   1     stage1         None None    0.00005

# %%
# test_path='/p/project1/hai_steerllms/GRouNdGAN//data/processed/PBMC/CrossVal_2000/PBMC68k_test.h5ad'
# fake_path="../results/PBMC/CrossVal_1000/KB_GPT/freq_2/GPT4/Seed1/TF10/GRouNdGAN/simulated_3.h5ad"
# real,fake=compute_tsne(test_path, fake_path)

# %%
# from teju_utils.plots import plot_tsne
# plot_tsne(real, fake)

# %%
metric='euclidean_distance'
# df[metric+'_fake_train'] = df.apply(lambda x: compute_euclidean(x['train_path'], x['fake_path']), axis=1)
df[metric+'_fake_test'] = df.apply(lambda x: compute_euclidean(x['test_path'], x['fake_path']), axis=1)
df_partial[metric+'_train_test'] = df_partial.apply(lambda x: compute_euclidean(x['test_path'], x['train_path']), axis=1)

# %%
df=df.fillna("None")
columns=[f'{metric}_fake_test']
df.groupby(['dataset', 'stage', 'knowledge_base', "freq", "method", "cross_val"]).agg(['mean', 'std'])[columns]
# Out:
#                                                            euclidean_distance_fake_test  \
#                                                                                    mean
# dataset    stage knowledge_base freq      method cross_val
# BoneMarrow 1     stage1         None      None   1000                         93.015886
#                                                  2000                        108.944677
#            2     GPT            freq_1    GPT4   1000                         75.032957
#                                                  2000                         89.130129
#                                           GRNB2  1000                         78.591019
# ...                                                                                 ...
# PBMC_CTL   2     Sapien         freq_None GPT4   2000                        283.820007
#                                           GRNB2  1000                         69.574545
#                                                  2000                         59.516781
#                                           Random 1000                         72.050150
#                                                  2000                         60.112204
#
#
#                                                                   std
# dataset    stage knowledge_base freq      method cross_val
# BoneMarrow 1     stage1         None      None   1000        7.739995
#                                                  2000       19.221421
#            2     GPT            freq_1    GPT4   1000        8.725919
#                                                  2000        5.358578
#                                           GRNB2  1000        3.309296
# ...                                                               ...
# PBMC_CTL   2     Sapien         freq_None GPT4   2000        0.881900
#                                           GRNB2  1000        3.636066
#                                                  2000        1.892125
#                                           Random 1000        1.412397
#                                                  2000        2.629518
#
# [94 rows x 2 columns]

# %%
metric='euclidean_distance'

df=df.fillna("None")
columns=[f'{metric}_fake_test']
df.groupby(['dataset', 'stage', 'knowledge_base', "freq", "method"]).agg(['mean', 'std'])[columns].round(0)
# Out:
#                                                    euclidean_distance_fake_test  \
#                                                                            mean
# dataset    stage knowledge_base freq        method
# BoneMarrow 1     stage1         None        None                          101.0
#            2     GPT            freq_1      GPT4                           82.0
#                                             GRNB2                          78.0
#                                             Random                         96.0
#                                 freq_2      GPT4                           88.0
#                                             GRNB2                          89.0
#                                             Random                         85.0
#                  Llama          freq_2      GRNB2                          78.0
#                  Random         freq_None   Random                         80.0
#                  Sapien         freq_None   GPT4                           86.0
#                                             GRNB2                          77.0
#                                             Random                         82.0
# PBMC       1     stage1         None        None                          107.0
#            2     GPT            freq_1      GPT4                           90.0
#                                             GRNB2                          83.0
#                                             Random                         92.0
#                                 freq_2      GPT4                          630.0
#                                             GRNB2                         616.0
#                                             Random                        118.0
#                  GPT-old        freq_1      GPT4                           90.0
#                                             GRNB2                          83.0
#                                 freq_2      GPT4                         1971.0
#                                             GRNB2                         616.0
#                  Llama          freq_1      GPT4                           97.0
#                                             GRNB2                          83.0
#                                             Random                        105.0
#                                 freq_2      GPT4                          110.0
#                                             GRNB2                         255.0
#                                             Random                        141.0
#                                 no_kb_gpt   GRNB2                         103.0
#                                 no_kb_human GRNB2                         102.0
#                  Random         freq_None   Random                        187.0
#                  Sapien         freq_None   GPT4                           89.0
#                                             GRNB2                         121.0
#                                             Llama                         193.0
#                                             Random                        121.0
# PBMC_CTL   1     stage1         None        None                           63.0
#            2     GPT            freq_1      GPT4                           67.0
#                                             GRNB2                          57.0
#                                             Random                         59.0
#                                 freq_2      GPT4                           71.0
#                                             GRNB2                          64.0
#                                             Random                         71.0
#                  Llama          freq_2      GRNB2                          45.0
#                  Random         freq_None   Random                         51.0
#                  Sapien         freq_None   GPT4                          176.0
#                                             GRNB2                          65.0
#                                             Random                         66.0
#
#
#                                                        std
# dataset    stage knowledge_base freq        method
# BoneMarrow 1     stage1         None        None      16.0
#            2     GPT            freq_1      GPT4      10.0
#                                             GRNB2      4.0
#                                             Random    13.0
#                                 freq_2      GPT4      18.0
#                                             GRNB2     19.0
#                                             Random     8.0
#                  Llama          freq_2      GRNB2      4.0
#                  Random         freq_None   Random     7.0
#                  Sapien         freq_None   GPT4       9.0
#                                             GRNB2      5.0
#                                             Random     6.0
# PBMC       1     stage1         None        None      15.0
#            2     GPT            freq_1      GPT4      13.0
#                                             GRNB2     17.0
#                                             Random    14.0
#                                 freq_2      GPT4     562.0
#                                             GRNB2    564.0
#                                             Random    13.0
#                  GPT-old        freq_1      GPT4      13.0
#                                             GRNB2     17.0
#                                 freq_2      GPT4    1995.0
#                                             GRNB2    565.0
#                  Llama          freq_1      GPT4      10.0
#                                             GRNB2     11.0
#                                             Random    17.0
#                                 freq_2      GPT4      12.0
#                                             GRNB2    119.0
#                                             Random    30.0
#                                 no_kb_gpt   GRNB2     17.0
#                                 no_kb_human GRNB2     38.0
#                  Random         freq_None   Random    79.0
#                  Sapien         freq_None   GPT4       7.0
#                                             GRNB2     25.0
#                                             Llama     52.0
#                                             Random    22.0
# PBMC_CTL   1     stage1         None        None       4.0
#            2     GPT            freq_1      GPT4      11.0
#                                             GRNB2      6.0
#                                             Random     7.0
#                                 freq_2      GPT4       8.0
#                                             GRNB2      6.0
#                                             Random     6.0
#                  Llama          freq_2      GRNB2      4.0
#                  Random         freq_None   Random     3.0
#                  Sapien         freq_None   GPT4     115.0
#                                             GRNB2      6.0
#                                             Random     7.0

# %%
df=df.fillna("None")
columns=[f'{metric}_fake_test']
df.groupby(['dataset', 'stage', 'knowledge_base', "freq", "method","cross_val"]).agg(['mean', 'std'])[columns]
# Out:
#                                                            euclidean_distance_fake_test  \
#                                                                                    mean
# dataset    stage knowledge_base freq      method cross_val
# BoneMarrow 1     stage1         None      None   1000                         93.015886
#                                                  2000                        108.944677
#            2     GPT            freq_1    GPT4   1000                         75.032957
#                                                  2000                         89.130129
#                                           GRNB2  1000                         78.591019
# ...                                                                                 ...
# PBMC_CTL   2     Sapien         freq_None GPT4   2000                        283.820007
#                                           GRNB2  1000                         69.574545
#                                                  2000                         59.516781
#                                           Random 1000                         72.050150
#                                                  2000                         60.112204
#
#
#                                                                   std
# dataset    stage knowledge_base freq      method cross_val
# BoneMarrow 1     stage1         None      None   1000        7.739995
#                                                  2000       19.221421
#            2     GPT            freq_1    GPT4   1000        8.725919
#                                                  2000        5.358578
#                                           GRNB2  1000        3.309296
# ...                                                               ...
# PBMC_CTL   2     Sapien         freq_None GPT4   2000        0.881900
#                                           GRNB2  1000        3.636066
#                                                  2000        1.892125
#                                           Random 1000        1.412397
#                                                  2000        2.629518
#
# [94 rows x 2 columns]

# %%
# compute_euclidean(test_path,"../results/PBMC/CrossVal_1000/KB_GPT/freq_2/GPT4/Seed1/TF10/GRouNdGAN/simulated_3.h5ad")

# %%
df_partial=df_partial.fillna("None")
columns=[f'{metric}_train_test']
df_partial.groupby(['dataset', 'stage', 'knowledge_base', "freq", "method"]).agg(['mean', 'std'])[columns].round(0)
# Out:
#                                             euclidean_distance_train_test  \
#                                                                      mean
# dataset    stage knowledge_base freq method
# BoneMarrow 1     stage1         None None                            80.0
# PBMC       1     stage1         None None                           100.0
# PBMC_CTL   1     stage1         None None                            57.0
#
#
#                                               std
# dataset    stage knowledge_base freq method
# BoneMarrow 1     stage1         None None     4.0
# PBMC       1     stage1         None None    16.0
# PBMC_CTL   1     stage1         None None     7.0

# %%
metric='random_forest'
# df[metric+'_fake_train'] = df.apply(lambda x: compute_auroc_rf(x['train_path'], x['fake_path']), axis=1)
df[metric+'_fake_test'] = df.apply(lambda x: compute_auroc_rf(x['test_path'], x['fake_path']), axis=1)
df_partial[metric+'_train_test'] = df_partial.apply(lambda x: compute_auroc_rf(x['test_path'], x['train_path']), axis=1)

# %%
metric='random_forest'
df=df.fillna("None")
columns=[f'{metric}_fake_test']
df.groupby(['dataset', 'stage', 'knowledge_base', "freq", "method"]).agg(['mean', 'std'])[columns].round(3)
# Out:
#                                                  random_forest_fake_test  \
#                                                                     mean
# dataset    stage knowledge_base freq      method
# BoneMarrow 1     stage1         None      None                     0.661
#            2     GPT            freq_1    GPT4                     0.716
#                                           GRNB2                    0.637
#                                           Random                   0.793
#                                 freq_2    GPT4                     0.684
#                                           GRNB2                    0.659
#                                           Random                   0.758
#                  Sapien         freq_None GPT4                     0.700
#                                           GRNB2                    0.638
#                                           Random                   0.747
# PBMC       1     stage1         None      None                     0.550
#            2     GPT            freq_1    GPT4                     0.857
#                                           GRNB2                    0.592
#                                           Random                   0.871
#                                 freq_2    GPT4                     0.922
#                                           GRNB2                    0.851
#                                           Random                   0.848
#                  GPT-old        freq_1    GPT4                     0.857
#                                           GRNB2                    0.592
#                                 freq_2    GPT4                     0.922
#                                           GRNB2                    0.851
#                  Llama          freq_1    GPT4                     0.790
#                                           GRNB2                    0.586
#                                           Random                   0.886
#                                 freq_2    GPT4                     0.844
#                                           GRNB2                    0.820
#                                           Random                   0.859
#                  Sapien         freq_None GPT4                     0.627
#                                           GRNB2                    0.733
#                                           Random                   0.846
# PBMC_CTL   1     stage1         None      None                     0.573
#            2     GPT            freq_1    GPT4                     0.705
#                                           GRNB2                    0.592
#                                           Random                   0.760
#                                 freq_2    GPT4                     0.731
#                                           GRNB2                    0.623
#                                           Random                   0.755
#                  Sapien         freq_None GPT4                     0.793
#                                           GRNB2                    0.588
#                                           Random                   0.747
#
#
#                                                     std
# dataset    stage knowledge_base freq      method
# BoneMarrow 1     stage1         None      None    0.037
#            2     GPT            freq_1    GPT4    0.044
#                                           GRNB2   0.033
#                                           Random  0.046
#                                 freq_2    GPT4    0.033
#                                           GRNB2   0.031
#                                           Random  0.034
#                  Sapien         freq_None GPT4    0.080
#                                           GRNB2   0.023
#                                           Random  0.041
# PBMC       1     stage1         None      None    0.021
#            2     GPT            freq_1    GPT4    0.018
#                                           GRNB2   0.028
#                                           Random  0.018
#                                 freq_2    GPT4    0.084
#                                           GRNB2   0.159
#                                           Random  0.020
#                  GPT-old        freq_1    GPT4    0.018
#                                           GRNB2   0.028
#                                 freq_2    GPT4    0.085
#                                           GRNB2   0.160
#                  Llama          freq_1    GPT4    0.024
#                                           GRNB2   0.018
#                                           Random  0.013
#                                 freq_2    GPT4    0.017
#                                           GRNB2   0.078
#                                           Random  0.017
#                  Sapien         freq_None GPT4    0.043
#                                           GRNB2   0.050
#                                           Random  0.019
# PBMC_CTL   1     stage1         None      None    0.030
#            2     GPT            freq_1    GPT4    0.025
#                                           GRNB2   0.019
#                                           Random  0.023
#                                 freq_2    GPT4    0.031
#                                           GRNB2   0.026
#                                           Random  0.028
#                  Sapien         freq_None GPT4    0.206
#                                           GRNB2   0.028
#                                           Random  0.021

# %%
df_partial=df_partial.fillna("None")
columns=[f'{metric}_train_test']
df_partial.groupby(['dataset', 'stage', 'knowledge_base', "freq", "method"]).agg(['mean', 'std'])[columns].round(3)
# Out:
#                                             random_forest_train_test
#                                                                 mean    std
# dataset    stage knowledge_base freq method
# BoneMarrow 1     stage1         None None                      0.604  0.037
# PBMC       1     stage1         None None                      0.486  0.017
# PBMC_CTL   1     stage1         None None                      0.541  0.007

# %%
metric='mmd'
# df[metric+'_fake_train'] = df.apply(lambda x: compute_mmd(x['train_path'], x['fake_path']), axis=1)
df[metric+'_fake_test'] = df.apply(lambda x: compute_mmd(x['test_path'], x['fake_path']), axis=1)
df_partial[metric+'_train_test'] = df_partial.apply(lambda x: compute_mmd(x['test_path'], x['train_path']), axis=1)

# %%
# import pandas as pd
# df=pd.read_csv("df_results_30.09.csv")
# df_partial=pd.read_csv("df_partial_results_30.09.csv")

# %%
metric='mmd'
df=df.fillna("None")
columns=[f'{metric}_fake_test']
df.groupby(['dataset', 'stage', 'knowledge_base', "freq", "method"]).agg(['mean', 'std'])[columns].round(4)
# Out:
#                                                  mmd_fake_test
#                                                           mean     std
# dataset    stage knowledge_base freq      method
# BoneMarrow 1     stage1         None      None          0.0197  0.0069
#            2     GPT            freq_1    GPT4          0.0137  0.0026
#                                           GRNB2         0.0119  0.0009
#                                           Random        0.0172  0.0037
#                                 freq_2    GPT4          0.0137  0.0027
#                                           GRNB2         0.0126  0.0021
#                                           Random        0.0150  0.0020
#                  Sapien         freq_None GPT4          0.0124  0.0006
#                                           GRNB2         0.0118  0.0008
#                                           Random        0.0150  0.0026
# PBMC       1     stage1         None      None          0.0057  0.0005
#            2     GPT            freq_1    GPT4          0.0206  0.0025
#                                           GRNB2         0.0069  0.0012
#                                           Random        0.0226  0.0020
#                                 freq_2    GPT4          0.1440  0.1363
#                                           GRNB2         0.2252  0.2314
#                                           Random        0.0158  0.0016
#                  GPT-old        freq_1    GPT4          0.0206  0.0025
#                                           GRNB2         0.0069  0.0012
#                                 freq_2    GPT4          0.6900  0.7200
#                                           GRNB2         0.1694  0.1718
#                  Llama          freq_1    GPT4          0.0105  0.0002
#                                           GRNB2         0.0064  0.0006
#                                           Random        0.0143  0.0006
#                                 freq_2    GPT4          0.0165  0.0008
#                                           GRNB2         0.0375  0.0342
#                                           Random        0.0187  0.0036
#                  Sapien         freq_None GPT4          0.0072  0.0012
#                                           GRNB2         0.0139  0.0058
#                                           Random        0.0166  0.0031
# PBMC_CTL   1     stage1         None      None          0.0049  0.0002
#            2     GPT            freq_1    GPT4          0.0067  0.0008
#                                           GRNB2         0.0049  0.0001
#                                           Random        0.0080  0.0002
#                                 freq_2    GPT4          0.0073  0.0008
#                                           GRNB2         0.0055  0.0002
#                                           Random        0.0087  0.0003
#                  Sapien         freq_None GPT4          0.0238  0.0197
#                                           GRNB2         0.0053  0.0002
#                                           Random        0.0085  0.0005

# %%
df=df.fillna("None")
columns=[f'{metric}_fake_test']
df.groupby(['dataset', 'stage', 'knowledge_base', "freq", "method", "cross_val"]).agg(['mean', 'std'])[columns]
# Out:
#                                                            mmd_fake_test  \
#                                                                     mean
# dataset    stage knowledge_base freq      method cross_val
# BoneMarrow 1     stage1         None      None   1000           0.014684
#                                                  2000           0.024714
#            2     GPT            freq_1    GPT4   1000           0.015996
#                                                  2000           0.011441
#                                           GRNB2  1000           0.012380
# ...                                                                  ...
# PBMC_CTL   2     Sapien         freq_None GPT4   2000           0.042236
#                                           GRNB2  1000           0.005367
#                                                  2000           0.005179
#                                           Random 1000           0.008905
#                                                  2000           0.008103
#
#
#                                                                  std
# dataset    stage knowledge_base freq      method cross_val
# BoneMarrow 1     stage1         None      None   1000       0.000616
#                                                  2000       0.006497
#            2     GPT            freq_1    GPT4   1000       0.001437
#                                                  2000       0.000537
#                                           GRNB2  1000       0.000756
# ...                                                              ...
# PBMC_CTL   2     Sapien         freq_None GPT4   2000       0.000454
#                                           GRNB2  1000       0.000070
#                                                  2000       0.000155
#                                           Random 1000       0.000426
#                                                  2000       0.000216
#
# [75 rows x 2 columns]

# %%
df_partial=df_partial.fillna("None")
columns=[f'{metric}_train_test']
df_partial.groupby(['dataset', 'stage', 'knowledge_base', "freq", "method"]).agg(['mean', 'std'])[columns].round(4)
# Out:
#                                             mmd_train_test
#                                                       mean     std
# dataset    stage knowledge_base freq method
# BoneMarrow 1     stage1         None None           0.0109  0.0007
# PBMC       1     stage1         None None           0.0051  0.0007
# PBMC_CTL   1     stage1         None None           0.0045  0.0002

# %%
columns=['cosine distance', 'euclidean distance', 'mmd', 'random forest', ]
df_partial=df_partial.fillna("None")
df_partial['knowledge_base']='control'
df_partial = df_partial.rename(columns={
    'cosine_distance_train_test': 'cosine distance',
    'euclidean_distance_train_test': 'euclidean distance',
    'mmd_train_test': 'mmd',
    'random_forest_train_test': 'random forest'
})
df_partial.groupby(['dataset', 'stage', 'knowledge_base', "freq", "method"]).agg(['mean', 'std'])[columns].round(5)
# Out:
#                                             cosine distance           \
#                                                        mean      std
# dataset    stage knowledge_base freq method
# BoneMarrow 1     control        None None           0.00205  0.00018
# PBMC       1     control        None None           0.00029  0.00008
# PBMC_CTL   1     control        None None           0.00020  0.00005
#
#                                             euclidean distance            \
#                                                           mean       std
# dataset    stage knowledge_base freq method
# BoneMarrow 1     control        None None             79.74648   3.71921
# PBMC       1     control        None None            100.10422  16.37898
# PBMC_CTL   1     control        None None             56.56772   7.49933
#
#                                                  mmd          random forest  \
#                                                 mean      std          mean
# dataset    stage knowledge_base freq method
# BoneMarrow 1     control        None None    0.01088  0.00069       0.60396
# PBMC       1     control        None None    0.00515  0.00068       0.48637
# PBMC_CTL   1     control        None None    0.00454  0.00023       0.54149
#
#
#                                                  std
# dataset    stage knowledge_base freq method
# BoneMarrow 1     control        None None    0.03671
# PBMC       1     control        None None    0.01703
# PBMC_CTL   1     control        None None    0.00721

# %%
df=df.fillna("None")
df = df.rename(columns={
    'cosine_distance_fake_test': 'cosine distance',
    'euclidean_distance_fake_test': 'euclidean distance',
    'mmd_fake_test': 'mmd',
    'random_forest_fake_test': 'random forest'
})
df
# Out:
#       tag                                          fake_path     dataset  \
# 0    fake  /p/project1/hai_steerllms/GRouNdGAN//results/P...        PBMC
# 1    fake  /p/project1/hai_steerllms/GRouNdGAN//results/P...        PBMC
# 2    fake  /p/project1/hai_steerllms/GRouNdGAN//results/P...        PBMC
# 3    fake  /p/project1/hai_steerllms/GRouNdGAN//results/P...        PBMC
# 5    fake  /p/project1/hai_steerllms/GRouNdGAN//results/P...        PBMC
# ..    ...                                                ...         ...
# 368  fake  /p/project1/hai_steerllms/GRouNdGAN//results/B...  BoneMarrow
# 370  fake  /p/project1/hai_steerllms/GRouNdGAN//results/B...  BoneMarrow
# 371  fake  /p/project1/hai_steerllms/GRouNdGAN//results/B...  BoneMarrow
# 372  fake  /p/project1/hai_steerllms/GRouNdGAN//results/B...  BoneMarrow
# 373  fake  /p/project1/hai_steerllms/GRouNdGAN//results/B...  BoneMarrow
#
#     cross_val knowledge_base stage    freq  method seed  TF  ...  \
# 0        1000        GPT-old     2  freq_1   GRNB2    1  10  ...
# 1        1000        GPT-old     2  freq_1   GRNB2    1  10  ...
# 2        1000        GPT-old     2  freq_1   GRNB2    1  10  ...
# 3        1000        GPT-old     2  freq_1   GRNB2    1  10  ...
# 5        1000        GPT-old     2  freq_1    GPT4    1  10  ...
# ..        ...            ...   ...     ...     ...  ...  ..  ...
# 368      2000            GPT     2  freq_2    GPT4    1  10  ...
# 370      2000            GPT     2  freq_2  Random    1  10  ...
# 371      2000            GPT     2  freq_2  Random    1  10  ...
# 372      2000            GPT     2  freq_2  Random    1  10  ...
# 373      2000            GPT     2  freq_2  Random    1  10  ...
#
#                                             valid_path perc_zeros_fake  \
# 0    /p/project1/hai_steerllms/GRouNdGAN//data/proc...         72.1585
# 1    /p/project1/hai_steerllms/GRouNdGAN//data/proc...         72.1377
# 2    /p/project1/hai_steerllms/GRouNdGAN//data/proc...         72.3278
# 3    /p/project1/hai_steerllms/GRouNdGAN//data/proc...         72.2007
# 5    /p/project1/hai_steerllms/GRouNdGAN//data/proc...         40.7819
# ..                                                 ...             ...
# 368  /p/project1/hai_steerllms/GRouNdGAN//data/proc...         38.4876
# 370  /p/project1/hai_steerllms/GRouNdGAN//data/proc...         28.8900
# 371  /p/project1/hai_steerllms/GRouNdGAN//data/proc...         28.6166
# 372  /p/project1/hai_steerllms/GRouNdGAN//data/proc...         28.5722
# 373  /p/project1/hai_steerllms/GRouNdGAN//data/proc...         29.0904
#
#     perc_zeros_train perc_zeros_test  perc_zeros_valid  \
# 0               None            None              None
# 1               None            None              None
# 2               None            None              None
# 3               None            None              None
# 5               None            None              None
# ..               ...             ...               ...
# 368             None            None              None
# 370             None            None              None
# 371             None            None              None
# 372             None            None              None
# 373             None            None              None
#
#     cosine_distance_fake_train cosine distance euclidean distance  \
# 0                     0.000190        0.000165          72.723030
# 1                     0.000216        0.000181          75.777443
# 2                     0.000168        0.000108          57.613693
# 3                     0.000220        0.000161          69.682762
# 5                     0.000228        0.000178          77.562469
# ..                         ...             ...                ...
# 368                   0.001086        0.002089          81.332565
# 370                   0.001388        0.002537          88.981308
# 371                   0.002233        0.002742          95.668808
# 372                   0.001586        0.002054          80.106552
# 373                   0.001807        0.002572          90.422127
#
#      random forest       mmd
# 0         0.596327  0.006608
# 1         0.553889  0.006886
# 2         0.572389  0.005403
# 3         0.598540  0.006760
# 5         0.883947  0.018525
# ..             ...       ...
# 368       0.641376  0.013234
# 370       0.754858  0.014161
# 371       0.717448  0.012822
# 372       0.747696  0.013077
# 373       0.778896  0.013606
#
# [300 rows x 23 columns]

# %%
df_combine=pd.concat([df_partial, df])
df_combine=df_combine.query("knowledge_base !='GPT-old'")

# %%
df_combine['knowledge_base'] = df_combine['knowledge_base'].apply(lambda x: '1-'+x if x == 'Sapien' else '2-'+x)

# %%
df_combine.groupby(['dataset', 'stage', 'knowledge_base', "freq", "method"]).agg(['mean', 'std'])[columns].round(2).loc[['PBMC', 'PBMC_CTL', 'BoneMarrow']]
# Out:
#                                                  cosine distance        \
#                                                             mean   std
# dataset    stage knowledge_base freq      method
# PBMC       1     2-control      None      None              0.00  0.00
#                  2-stage1       None      None              0.00  0.00
#            2     1-Sapien       freq_None GPT4              0.00  0.00
#                                           GRNB2             0.00  0.00
#                                           Random            0.00  0.00
#                  2-GPT          freq_1    GPT4              0.00  0.00
#                                           GRNB2             0.00  0.00
#                                           Random            0.00  0.00
#                                 freq_2    GPT4              0.02  0.02
#                                           GRNB2             0.02  0.02
#                                           Random            0.00  0.00
#                  2-Llama        freq_1    GPT4              0.00  0.00
#                                           GRNB2             0.00  0.00
#                                           Random            0.00  0.00
#                                 freq_2    GPT4              0.00  0.00
#                                           GRNB2             0.00  0.00
#                                           Random            0.00  0.00
# PBMC_CTL   1     2-control      None      None              0.00  0.00
#                  2-stage1       None      None              0.00  0.00
#            2     1-Sapien       freq_None GPT4              0.00  0.00
#                                           GRNB2             0.00  0.00
#                                           Random            0.00  0.00
#                  2-GPT          freq_1    GPT4              0.00  0.00
#                                           GRNB2             0.00  0.00
#                                           Random            0.00  0.00
#                                 freq_2    GPT4              0.00  0.00
#                                           GRNB2             0.00  0.00
#                                           Random            0.00  0.00
# BoneMarrow 1     2-control      None      None              0.00  0.00
#                  2-stage1       None      None              0.00  0.00
#            2     1-Sapien       freq_None GPT4              0.00  0.00
#                                           GRNB2             0.00  0.00
#                                           Random            0.00  0.00
#                  2-GPT          freq_1    GPT4              0.00  0.00
#                                           GRNB2             0.00  0.00
#                                           Random            0.00  0.00
#                                 freq_2    GPT4              0.00  0.00
#                                           GRNB2             0.00  0.00
#                                           Random            0.00  0.00
#
#                                                  euclidean distance          \
#                                                                mean     std
# dataset    stage knowledge_base freq      method
# PBMC       1     2-control      None      None               100.10   16.38
#                  2-stage1       None      None               107.49   15.34
#            2     1-Sapien       freq_None GPT4                88.96    7.44
#                                           GRNB2              120.70   24.95
#                                           Random             120.91   22.30
#                  2-GPT          freq_1    GPT4                90.49   13.42
#                                           GRNB2               83.01   16.78
#                                           Random              91.83   14.14
#                                 freq_2    GPT4               629.98  562.07
#                                           GRNB2              615.53  564.27
#                                           Random             117.66   13.24
#                  2-Llama        freq_1    GPT4               100.36    8.40
#                                           GRNB2               73.59    2.10
#                                           Random              89.44    1.41
#                                 freq_2    GPT4               109.78   12.23
#                                           GRNB2              254.99  118.54
#                                           Random             140.65   30.43
# PBMC_CTL   1     2-control      None      None                56.57    7.50
#                  2-stage1       None      None                62.81    4.35
#            2     1-Sapien       freq_None GPT4               176.33  114.93
#                                           GRNB2               64.55    6.01
#                                           Random              66.08    6.67
#                  2-GPT          freq_1    GPT4                66.78   10.74
#                                           GRNB2               56.84    5.71
#                                           Random              59.19    7.22
#                                 freq_2    GPT4                70.66    7.78
#                                           GRNB2               63.88    5.57
#                                           Random              70.52    5.86
# BoneMarrow 1     2-control      None      None                79.75    3.72
#                  2-stage1       None      None               100.98   16.02
#            2     1-Sapien       freq_None GPT4                85.93    9.03
#                                           GRNB2               76.72    4.59
#                                           Random              82.22    5.82
#                  2-GPT          freq_1    GPT4                82.08   10.09
#                                           GRNB2               77.61    4.37
#                                           Random              96.40   13.10
#                                 freq_2    GPT4                87.83   17.59
#                                           GRNB2               88.82   18.59
#                                           Random              85.13    8.46
#
#                                                    mmd       random forest  \
#                                                   mean   std          mean
# dataset    stage knowledge_base freq      method
# PBMC       1     2-control      None      None    0.01  0.00          0.49
#                  2-stage1       None      None    0.01  0.00          0.55
#            2     1-Sapien       freq_None GPT4    0.01  0.00          0.63
#                                           GRNB2   0.01  0.01          0.73
#                                           Random  0.02  0.00          0.85
#                  2-GPT          freq_1    GPT4    0.02  0.00          0.86
#                                           GRNB2   0.01  0.00          0.59
#                                           Random  0.02  0.00          0.87
#                                 freq_2    GPT4    0.14  0.14          0.92
#                                           GRNB2   0.23  0.23          0.85
#                                           Random  0.02  0.00          0.85
#                  2-Llama        freq_1    GPT4    0.01  0.00          0.79
#                                           GRNB2   0.01  0.00          0.59
#                                           Random  0.01  0.00          0.89
#                                 freq_2    GPT4    0.02  0.00          0.84
#                                           GRNB2   0.04  0.03          0.82
#                                           Random  0.02  0.00          0.86
# PBMC_CTL   1     2-control      None      None    0.00  0.00          0.54
#                  2-stage1       None      None    0.00  0.00          0.57
#            2     1-Sapien       freq_None GPT4    0.02  0.02          0.79
#                                           GRNB2   0.01  0.00          0.59
#                                           Random  0.01  0.00          0.75
#                  2-GPT          freq_1    GPT4    0.01  0.00          0.70
#                                           GRNB2   0.00  0.00          0.59
#                                           Random  0.01  0.00          0.76
#                                 freq_2    GPT4    0.01  0.00          0.73
#                                           GRNB2   0.01  0.00          0.62
#                                           Random  0.01  0.00          0.76
# BoneMarrow 1     2-control      None      None    0.01  0.00          0.60
#                  2-stage1       None      None    0.02  0.01          0.66
#            2     1-Sapien       freq_None GPT4    0.01  0.00          0.70
#                                           GRNB2   0.01  0.00          0.64
#                                           Random  0.01  0.00          0.75
#                  2-GPT          freq_1    GPT4    0.01  0.00          0.72
#                                           GRNB2   0.01  0.00          0.64
#                                           Random  0.02  0.00          0.79
#                                 freq_2    GPT4    0.01  0.00          0.68
#                                           GRNB2   0.01  0.00          0.66
#                                           Random  0.02  0.00          0.76
#
#
#                                                    std
# dataset    stage knowledge_base freq      method
# PBMC       1     2-control      None      None    0.02
#                  2-stage1       None      None    0.02
#            2     1-Sapien       freq_None GPT4    0.04
#                                           GRNB2   0.05
#                                           Random  0.02
#                  2-GPT          freq_1    GPT4    0.02
#                                           GRNB2   0.03
#                                           Random  0.02
#                                 freq_2    GPT4    0.08
#                                           GRNB2   0.16
#                                           Random  0.02
#                  2-Llama        freq_1    GPT4    0.02
#                                           GRNB2   0.02
#                                           Random  0.01
#                                 freq_2    GPT4    0.02
#                                           GRNB2   0.08
#                                           Random  0.02
# PBMC_CTL   1     2-control      None      None    0.01
#                  2-stage1       None      None    0.03
#            2     1-Sapien       freq_None GPT4    0.21
#                                           GRNB2   0.03
#                                           Random  0.02
#                  2-GPT          freq_1    GPT4    0.03
#                                           GRNB2   0.02
#                                           Random  0.02
#                                 freq_2    GPT4    0.03
#                                           GRNB2   0.03
#                                           Random  0.03
# BoneMarrow 1     2-control      None      None    0.04
#                  2-stage1       None      None    0.04
#            2     1-Sapien       freq_None GPT4    0.08
#                                           GRNB2   0.02
#                                           Random  0.04
#                  2-GPT          freq_1    GPT4    0.04
#                                           GRNB2   0.03
#                                           Random  0.05
#                                 freq_2    GPT4    0.03
#                                           GRNB2   0.03
#                                           Random  0.03

# %%
df=df.fillna("None")
columns=['cosine_distance_fake_test', 'euclidean_distance_fake_test', 'mmd_fake_test', 'random_forest_fake_test', ]
df.groupby(['dataset', 'stage', 'knowledge_base', "freq", "method","cross_val"]).agg(['mean', 'std'])[columns].round(5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_21029/1432320025.py in <module>
#       1 df=df.fillna("None")
#       2 columns=['cosine_distance_fake_test', 'euclidean_distance_fake_test', 'mmd_fake_test', 'random_forest_fake_test', ]
# ----> 3 df.groupby(['dataset', 'stage', 'knowledge_base', "freq", "method","cross_val"]).agg(['mean', 'std'])[columns].round(5)
#
# /p/project1/hai_diffprivtab/local/python3.9/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3459             if is_iterator(key):
#    3460                 key = list(key)
# -> 3461             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3462
#    3463         # take() does not accept boolean indexers
#
# /p/project1/hai_diffprivtab/local/python3.9/lib/python3.9/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1300             # Have the index compute an indexer or return None
#    1301             # if it cannot handle:
# -> 1302             indexer = ax._convert_listlike_indexer(keyarr)
#    1303             # We only act on all found values:
#    1304             if indexer is not None and (indexer != -1).all():
#
# /p/project1/hai_diffprivtab/local/python3.9/lib/python3.9/site-packages/pandas/core/indexes/multi.py in _convert_listlike_indexer(self, keyarr)
#    2609             mask = check == -1
#    2610             if mask.any():
# -> 2611                 raise KeyError(f"{keyarr[mask]} not in index")
#    2612             elif is_empty_indexer(indexer, keyarr):
#    2613                 # We get here when levels still contain values which are not
#
# KeyError: "['cosine_distance_fake_test' 'euclidean_distance_fake_test'\n 'mmd_fake_test' 'random_forest_fake_test'] not in index"

# %%
# df.to_csv("results_23.09.csv",index=None)

# %%
# dataset='PBMC'
# cross_val=1000
# real_test=df.query(f"tag=='real_test' and dataset=='{dataset}' and cross_val=='{cross_val}'").file_path.values[0]
# fake_list=df.query(f"tag=='fake' and dataset=='{dataset}' and cross_val=='{cross_val}'").file_path.values

# %%
for dataset in ["PBMC", "PBMC_CTL", "BoneMarrow"]:

    print(f"*******{dataset}")
    if dataset == "PBMC":
        train_data = sc.read_h5ad('../data/processed/PBMC/PBMC68k_train.h5ad')
        test_data = sc.read_h5ad('../data/processed/PBMC/PBMC68k_test.h5ad')
        valid_data = sc.read_h5ad('../data/processed/PBMC/PBMC68k_validation.h5ad')
    elif dataset == "PBMC_CTL":
        train_data = sc.read_h5ad('../data/processed/PBMC_CTL/PBMC_CTL20k_train.h5ad')
        test_data = sc.read_h5ad('../data/processed/PBMC_CTL/PBMC_CTL20k_test.h5ad')
        valid_data = sc.read_h5ad('../data/processed/PBMC_CTL/PBMC_CTL20k_validation.h5ad')
    elif dataset == "BoneMarrow":
        train_data = sc.read_h5ad('../data/processed/BoneMarrow/BoneMarrow2k_train.h5ad')
        test_data = sc.read_h5ad('../data/processed/BoneMarrow/BoneMarrow2k_test.h5ad')
        valid_data = sc.read_h5ad('../data/processed/BoneMarrow/BoneMarrow2k_validation.h5ad')
    else:
        break
    
    train_array = get_array(train_data)
    test_array = get_array(test_data)
    valid_array = get_array(valid_data)
    print(train_array.shape, test_array.shape, valid_array.shape)

    for data in [train_array, test_array, valid_array]:
        print(f"{calculate_perc_zeros(data):.3f}")
        
    
    real_embedding, simulated_embedding = compute_tsne(test_array, valid_array)
    plot_tsne(real_embedding, simulated_embedding, "real (valid)")
    plt.title(dataset)
    plt.show()
    
    
    np.random.seed(42)
    randint = np.random.randint(0, len(train_array), len(test_array))

    real_embedding, simulated_embedding = compute_tsne(test_array, train_array[randint])
    plot_tsne(real_embedding, simulated_embedding, "real (train)")
    plt.title(dataset)
    plt.show()

# %%
for dataset in ["PBMC", "PBMC_CTL", "BoneMarrow"]:

    print(f"*******{dataset}")
    if dataset == "PBMC":
        train_data = sc.read_h5ad('../data/processed/PBMC/PBMC68k_train.h5ad')
        test_data = sc.read_h5ad('../data/processed/PBMC/PBMC68k_test.h5ad')
        valid_data = sc.read_h5ad('../data/processed/PBMC/PBMC68k_validation.h5ad')
    elif dataset == "PBMC_CTL":
        train_data = sc.read_h5ad('../data/processed/PBMC_CTL/PBMC_CTL20k_train.h5ad')
        test_data = sc.read_h5ad('../data/processed/PBMC_CTL/PBMC_CTL20k_test.h5ad')
        valid_data = sc.read_h5ad('../data/processed/PBMC_CTL/PBMC_CTL20k_validation.h5ad')
    elif dataset == "BoneMarrow":
        train_data = sc.read_h5ad('../data/processed/BoneMarrow/BoneMarrow2k_train.h5ad')
        test_data = sc.read_h5ad('../data/processed/BoneMarrow/BoneMarrow2k_test.h5ad')
        valid_data = sc.read_h5ad('../data/processed/BoneMarrow/BoneMarrow2k_validation.h5ad')
    else:
        break
    
    cc_data = sc.read_h5ad(f'../results/{dataset}/Stage1_Gene1000_CC200000_TF10/GRouNdGAN_CC/simulated.h5ad')
    train_array = get_array(train_data)
    test_array = get_array(test_data)
    valid_array = get_array(valid_data)
    cc_array = get_array(cc_data)
    
    print(train_array.shape, test_array.shape, valid_array.shape, cc_array.shape)
    
    
    

    for data in [train_array, test_array, valid_array, cc_array]:
        print(f"{calculate_perc_zeros(data):.3f}")
        
    np.random.seed(42)
    randint = np.random.randint(0, len(cc_array), len(test_array))
    real_embedding, simulated_embedding = compute_tsne(test_array, cc_array[randint])
    plot_tsne(real_embedding, simulated_embedding, "simulated (Stage1)")
    plt.title(dataset)
    plt.show()

# %%
for dataset in ["PBMC_CTL"]:

    print(f"*******{dataset}")
    if dataset == "PBMC":
        train_data = sc.read_h5ad('../data/processed/PBMC/PBMC68k_train.h5ad')
        test_data = sc.read_h5ad('../data/processed/PBMC/PBMC68k_test.h5ad')
        valid_data = sc.read_h5ad('../data/processed/PBMC/PBMC68k_validation.h5ad')
    elif dataset == "PBMC_CTL":
        train_data = sc.read_h5ad('../data/processed/PBMC_CTL/PBMC_CTL20k_train.h5ad')
        test_data = sc.read_h5ad('../data/processed/PBMC_CTL/PBMC_CTL20k_test.h5ad')
        valid_data = sc.read_h5ad('../data/processed/PBMC_CTL/PBMC_CTL20k_validation.h5ad')
    elif dataset == "BoneMarrow":
        train_data = sc.read_h5ad('../data/processed/BoneMarrow/BoneMarrow2k_train.h5ad')
        test_data = sc.read_h5ad('../data/processed/BoneMarrow/BoneMarrow2k_test.h5ad')
        valid_data = sc.read_h5ad('../data/processed/BoneMarrow/BoneMarrow2k_validation.h5ad')
    else:
        break
    

    train_array = get_array(train_data)
    test_array = get_array(test_data)
    valid_array = get_array(valid_data)
   
    
    print(train_array.shape, test_array.shape, valid_array.shape)
    
    tf10_data = sc.read_h5ad(f'../results/{dataset}/GRNBoost2/Gene1000_CC200000_TF10_seed1/GRouNdGAN/simulated_130k.h5ad')
    tf15_data = sc.read_h5ad(f'../results/{dataset}/GRNBoost2/Gene1000_CC200000_TF15_seed1/GRouNdGAN/simulated.h5ad')

    tf10_array = get_array(tf10_data)
    tf15_array = get_array(tf15_data)
    
    

    for data in [train_array, test_array, valid_array, tf10_array, tf15_array]:
        print(f"{calculate_perc_zeros(data):.3f}")
        
    np.random.seed(42)
    randint = np.random.randint(0, len(tf10_array), len(test_array))
    real_embedding, simulated_embedding = compute_tsne(test_array, tf10_array[randint])
    plot_tsne(real_embedding, simulated_embedding, "simulated (Stage2 - TF10)")
    plt.title(dataset)
    plt.show()
    
    randint = np.random.randint(0, len(tf15_array), len(test_array))
    real_embedding, simulated_embedding = compute_tsne(test_array, tf15_array[randint])
    plot_tsne(real_embedding, simulated_embedding, "simulated (Stage2 - TF15)")
    plt.title(dataset)
    plt.show()

# %%
for dataset in ["PBMC_CTL"]:

    print(f"*******{dataset}")
    if dataset == "PBMC":
        train_data = sc.read_h5ad('../data/processed/PBMC/PBMC68k_train.h5ad')
        test_data = sc.read_h5ad('../data/processed/PBMC/PBMC68k_test.h5ad')
        valid_data = sc.read_h5ad('../data/processed/PBMC/PBMC68k_validation.h5ad')
    elif dataset == "PBMC_CTL":
        train_data = sc.read_h5ad('../data/processed/PBMC_CTL/PBMC_CTL20k_train.h5ad')
        test_data = sc.read_h5ad('../data/processed/PBMC_CTL/PBMC_CTL20k_test.h5ad')
        valid_data = sc.read_h5ad('../data/processed/PBMC_CTL/PBMC_CTL20k_validation.h5ad')
    elif dataset == "BoneMarrow":
        train_data = sc.read_h5ad('../data/processed/BoneMarrow/BoneMarrow2k_train.h5ad')
        test_data = sc.read_h5ad('../data/processed/BoneMarrow/BoneMarrow2k_test.h5ad')
        valid_data = sc.read_h5ad('../data/processed/BoneMarrow/BoneMarrow2k_validation.h5ad')
    else:
        break
    

    train_array = get_array(train_data)
    test_array = get_array(test_data)
    valid_array = get_array(valid_data)
   
    
    print(train_array.shape, test_array.shape, valid_array.shape)
    
    tf10_data = sc.read_h5ad(f'../results/{dataset}/GRNBoost2/Gene1000_CC200000_TF10_seed1/GRouNdGAN/simulated.h5ad')
    # tf15_data = sc.read_h5ad(f'../results/{dataset}/GRNBoost2/Gene1000_CC200000_TF15_seed1/GRouNdGAN/simulated.h5ad')

    tf10_array = get_array(tf10_data)
    # tf15_array = get_array(tf15_data)
    
    

    for data in [train_array, test_array, valid_array, tf10_array]:
        print(f"{calculate_perc_zeros(data):.3f}")
        
    np.random.seed(42)
    randint = np.random.randint(0, len(tf10_array), len(test_array))
    real_embedding, simulated_embedding = compute_tsne(test_array, tf10_array[randint])
    plot_tsne(real_embedding, simulated_embedding, "simulated (Stage2-240k - TF10)")
    plt.title(dataset)
    plt.show()

# %%
for dataset in ["PBMC_CTL"]:

    print(f"*******{dataset}")
    if dataset == "PBMC":
        train_data = sc.read_h5ad('../data/processed/PBMC/PBMC68k_train.h5ad')
        test_data = sc.read_h5ad('../data/processed/PBMC/PBMC68k_test.h5ad')
        valid_data = sc.read_h5ad('../data/processed/PBMC/PBMC68k_validation.h5ad')
    elif dataset == "PBMC_CTL":
        train_data = sc.read_h5ad('../data/processed/PBMC_CTL/PBMC_CTL20k_train.h5ad')
        test_data = sc.read_h5ad('../data/processed/PBMC_CTL/PBMC_CTL20k_test.h5ad')
        valid_data = sc.read_h5ad('../data/processed/PBMC_CTL/PBMC_CTL20k_validation.h5ad')
    elif dataset == "BoneMarrow":
        train_data = sc.read_h5ad('../data/processed/BoneMarrow/BoneMarrow2k_train.h5ad')
        test_data = sc.read_h5ad('../data/processed/BoneMarrow/BoneMarrow2k_test.h5ad')
        valid_data = sc.read_h5ad('../data/processed/BoneMarrow/BoneMarrow2k_validation.h5ad')
    else:
        break
    

    train_array = get_array(train_data)
    test_array = get_array(test_data)
    valid_array = get_array(valid_data)
   
    
    
    
    tf10_bottom_data = sc.read_h5ad(f'../results/{dataset}/GRNBoost2/Gene1000_CC200000_Bottom_TF10_seed1/GRouNdGAN/simulated.h5ad')

    tf10_bottom_array = get_array(tf10_bottom_data)
    
    print(train_array.shape, test_array.shape, valid_array.shape, tf10_bottom_array.shape)
    
    

    for data in [train_array, test_array, valid_array, tf10_bottom_array]:
        print(f"{calculate_perc_zeros(data):.3f}")
        
    np.random.seed(42)
    randint = np.random.randint(0, len(tf10_bottom_array), len(test_array))
    real_embedding, simulated_embedding = compute_tsne(test_array, tf10_bottom_array[randint])
    plot_tsne(real_embedding, simulated_embedding, "simulated (Stage2 - Bottom TF10)")
    plt.title(dataset)
    plt.show()

# %%
for dataset in ["PBMC", "BoneMarrow"]:

    print(f"*******{dataset}")
    if dataset == "PBMC":
        train_data = sc.read_h5ad('../data/processed/PBMC/PBMC68k_train.h5ad')
        test_data = sc.read_h5ad('../data/processed/PBMC/PBMC68k_test.h5ad')
        valid_data = sc.read_h5ad('../data/processed/PBMC/PBMC68k_validation.h5ad')
    elif dataset == "PBMC_CTL":
        train_data = sc.read_h5ad('../data/processed/PBMC_CTL/PBMC_CTL20k_train.h5ad')
        test_data = sc.read_h5ad('../data/processed/PBMC_CTL/PBMC_CTL20k_test.h5ad')
        valid_data = sc.read_h5ad('../data/processed/PBMC_CTL/PBMC_CTL20k_validation.h5ad')
    elif dataset == "BoneMarrow":
        train_data = sc.read_h5ad('../data/processed/BoneMarrow/BoneMarrow2k_train.h5ad')
        test_data = sc.read_h5ad('../data/processed/BoneMarrow/BoneMarrow2k_test.h5ad')
        valid_data = sc.read_h5ad('../data/processed/BoneMarrow/BoneMarrow2k_validation.h5ad')
    else:
        break
    
    stage2_gt_data = sc.read_h5ad(f'../results/{dataset}/GRNBoost2/Gene1000_CC200000_TF10_seed1/GRouNdGAN/simulated.h5ad')
    train_array = get_array(train_data)
    test_array = get_array(test_data)
    valid_array = get_array(valid_data)
    stage2_gt_array = get_array(stage2_gt_data)
    
    print(train_array.shape, test_array.shape, valid_array.shape, stage2_gt_array.shape)
    
    
    

    for data in [train_array, test_array, valid_array, stage2_gt_array]:
        print(f"{calculate_perc_zeros(data):.3f}")
        
    np.random.seed(42)
    randint = np.random.randint(0, len(stage2_gt_array), len(test_array))
    real_embedding, simulated_embedding = compute_tsne(test_array, stage2_gt_array[randint])
    plot_tsne(real_embedding, simulated_embedding, "Stage2 - GRNBoost2")
    plt.title(dataset)
    plt.show()

# %%
dataset = "LinearUniform"
print(f"*******{dataset}")
train_data = sc.read_h5ad('../data/processed/LinearUniform/LinearUniform5k_train.h5ad')
test_data = sc.read_h5ad('../data/processed/LinearUniform/LinearUniform5k_test.h5ad')
valid_data = sc.read_h5ad('../data/processed/LinearUniform/LinearUniform5k_validation.h5ad')

stage1_data = sc.read_h5ad(f'../results/{dataset}/Stage1_Gene100_CC200000_TF10/GRouNdGAN_CC/simulated.h5ad')
stage2_data = sc.read_h5ad(f'../results/{dataset}/Gene100_CC200000_TF10_seed1/GRouNdGAN/simulated.h5ad')
train_array = get_array(train_data)
test_array = get_array(test_data)
valid_array = get_array(valid_data)

stage1_array = get_array(stage1_data)
stage2_array = get_array(stage2_data)

print(train_array.shape, test_array.shape, valid_array.shape, stage1_array.shape, stage2_array.shape)




for data in [train_array, test_array, valid_array, stage1_array, stage2_array]:
    print(f"{calculate_perc_zeros(data):.3f}")
    
np.random.seed(42)

randint = np.random.randint(0, len(train_array), len(test_array))
real_embedding, simulated_embedding = compute_tsne(test_array, train_array[randint])
plot_tsne(real_embedding, simulated_embedding, "real (train)")
plt.title(dataset)
plt.show()

randint = np.random.randint(0, len(stage2_array), len(test_array))
real_embedding, simulated_embedding = compute_tsne(test_array, stage2_array[randint])
plot_tsne(real_embedding, simulated_embedding, "Stage2 - LinearUniform")
plt.title(dataset)
plt.show()

randint = np.random.randint(0, len(stage1_array), len(test_array))
real_embedding, simulated_embedding = compute_tsne(test_array, stage1_array[randint])
plot_tsne(real_embedding, simulated_embedding, "Stage1 - LinearUniform")

plt.title(dataset)
plt.show()

# %%
ls ../data/processed/LinearUniform

# %%
# test_data = sc.read_h5ad('../data/processed/BoneMarrow/BoneMarrow2k_test.h5ad')
# valid_data = sc.read_h5ad('../data/processed/BoneMarrow/BoneMarrow2k_validation.h5ad')
# print(test_data.X.shape, valid_data.X.shape)

# %%
from scipy.sparse import issparse
import copy

def compute_all_distances(real_cells, simulated_cells):
    real_cells = copy.deepcopy(real_cells)
    simulated_cells = copy.deepcopy(simulated_cells)
    
    dists_pw=[]
    dists_5nn=[]
    dists_1nn=[]
    euclideans=[]
    cosines=[]
    mmds=[]
    perc_zeros_diffs=[]
    gowers=[]
    sim_reals, sim_synths, sim_crosses=[],[],[]
    
    if issparse(real_cells):
        real_cells = real_cells.toarray()
    
    if issparse(simulated_cells):
        simulated_cells = simulated_cells.toarray()
    
    seeds = [42, 43, 44, 45, 46]
    
    for seed in seeds:
        np.random.seed(seed)
        
        if len(real_cells) > 1000:
            randint_real = np.random.randint(0, len(real_cells), 1000)
            real_cells_subset = real_cells[randint_real]
        else:
            real_cells_subset = real_cells
        
        if len(simulated_cells) > len(real_cells_subset):
            randint_sim = np.random.randint(0, len(simulated_cells), len(real_cells_subset))
            simulated_cells_subset = simulated_cells[randint_sim]
        else:
            simulated_cells_subset = simulated_cells
            
        
        
        
        real_perc_zeros = calculate_perc_zeros(real_cells_subset)
        simulated_perc_zeros = calculate_perc_zeros(simulated_cells_subset)
        perc_zeros_diff = real_perc_zeros - simulated_perc_zeros
        perc_zeros_diffs.append(round(perc_zeros_diff, 3))
        
        # print(real_perc_zeros, simulated_perc_zeros)

        d_pairwise = compute_pairwise_distance(real_cells_subset, simulated_cells_subset)
        d_5nn = compute_knn_distance(real_cells_subset, simulated_cells_subset, k=5)
        d_1nn = compute_knn_distance(real_cells_subset, simulated_cells_subset, k=1)
        d_euclidean = compute_euclidean(real_cells_subset, simulated_cells_subset)
        d_cosine = compute_cosine(real_cells_subset, simulated_cells_subset)
        # d_gower, sim_real, sim_synth, sim_cross  = gower_score(real_cells_subset, simulated_cells_subset)
        
        d_mmd = compute_mmd(real_cells_subset, simulated_cells_subset)
        # print("MMD distance:", mmd_distance)
        
        dists_pw.append(d_pairwise)
        dists_5nn.append(d_5nn)
        dists_1nn.append(d_1nn)
        euclideans.append(d_euclidean)
        cosines.append(d_cosine)
        mmds.append(d_mmd)
        # gowers.append(d_gower)
        
        # plt.hist(sim_real)
        # plt.show()
        # plt.hist(sim_synth)
        # plt.show()
        # plt.hist(sim_cross)
        # plt.show()
        
    # return pd.DataFrame(zip(perc_zeros_diffs, dists_pw, dists_5nn, dists_1nn, gowers, euclideans, cosines, mmds, seeds), columns=['Perc_zeros_diff', 'Pairwise', '5-NN', '1-NN', 'Gower', 'Euclidean', 'Cosine', 'MMD', 'seed'])
    return pd.DataFrame(zip(perc_zeros_diffs, dists_pw, dists_5nn, dists_1nn, euclideans, cosines, mmds, seeds), columns=['Perc_zeros_diff', 'Pairwise', '5-NN', '1-NN', 'Euclidean', 'Cosine', 'MMD', 'seed'])

# %%
global_df=[]
# global_df_ = pd.concat(global_df)

# %%
setting="real"
# for dataset in ["PBMC", "PBMC_CTL", "BoneMarrow", "LinearUniform"]:
for dataset in ["LinearUniform"]:

    print(f"*******{dataset}")
    if dataset == "PBMC":
        train_data = sc.read_h5ad('../data/processed/PBMC/PBMC68k_train.h5ad')
        test_data = sc.read_h5ad('../data/processed/PBMC/PBMC68k_test.h5ad')
        valid_data = sc.read_h5ad('../data/processed/PBMC/PBMC68k_validation.h5ad')
    elif dataset == "PBMC_CTL":
        train_data = sc.read_h5ad('../data/processed/PBMC_CTL/PBMC_CTL20k_train.h5ad')
        test_data = sc.read_h5ad('../data/processed/PBMC_CTL/PBMC_CTL20k_test.h5ad')
        valid_data = sc.read_h5ad('../data/processed/PBMC_CTL/PBMC_CTL20k_validation.h5ad')
    elif dataset == "BoneMarrow":
        train_data = sc.read_h5ad('../data/processed/BoneMarrow/BoneMarrow2k_train.h5ad')
        test_data = sc.read_h5ad('../data/processed/BoneMarrow/BoneMarrow2k_test.h5ad')
        valid_data = sc.read_h5ad('../data/processed/BoneMarrow/BoneMarrow2k_validation.h5ad')
    elif dataset == "LinearUniform":
        train_data = sc.read_h5ad('../data/processed/LinearUniform/LinearUniform5k_train.h5ad')
        test_data = sc.read_h5ad('../data/processed/LinearUniform/LinearUniform5k_test.h5ad')
        valid_data = sc.read_h5ad('../data/processed/LinearUniform/LinearUniform5k_validation.h5ad')
        
    else:
        break
    
    train_array = get_array(train_data)
    test_array = get_array(test_data)
    valid_array = get_array(valid_data)
    
    
    # if dataset in global_df_.dataset.unique():
    #     continue
    
    dist_df=compute_all_distances(test_array, test_array)
    dist_df['tag'] = "Real (Test vs Test)"
    dist_df['dataset'] = dataset
    dist_df["setting"] = setting
    global_df.append(dist_df)
    
    dist_df=compute_all_distances(test_array, valid_array)
    dist_df['tag'] = "Real (Test vs Valid)"
    dist_df['dataset'] = dataset
    global_df.append(dist_df)
    
    
    dist_df=compute_all_distances(test_array, train_array)
    dist_df['tag'] = "Real (Test vs Train)"
    dist_df['dataset'] = dataset
    dist_df["setting"] = setting
    global_df.append(dist_df)

# %%
setting="stage1"
# for dataset in ["PBMC", "PBMC_CTL", "BoneMarrow", "LinearUniform"]:
for dataset in ["LinearUniform"]:
    print(f"*******{dataset}")
    if dataset == "PBMC":
        train_data = sc.read_h5ad('../data/processed/PBMC/PBMC68k_train.h5ad')
        test_data = sc.read_h5ad('../data/processed/PBMC/PBMC68k_test.h5ad')
        valid_data = sc.read_h5ad('../data/processed/PBMC/PBMC68k_validation.h5ad')
        cc_data = sc.read_h5ad(f'../results/{dataset}/Stage1_Gene1000_CC200000_TF10/GRouNdGAN_CC/simulated.h5ad')
    elif dataset == "PBMC_CTL":
        train_data = sc.read_h5ad('../data/processed/PBMC_CTL/PBMC_CTL20k_train.h5ad')
        test_data = sc.read_h5ad('../data/processed/PBMC_CTL/PBMC_CTL20k_test.h5ad')
        valid_data = sc.read_h5ad('../data/processed/PBMC_CTL/PBMC_CTL20k_validation.h5ad')
        cc_data = sc.read_h5ad(f'../results/{dataset}/Stage1_Gene1000_CC200000_TF10/GRouNdGAN_CC/simulated.h5ad')
    elif dataset == "BoneMarrow":
        train_data = sc.read_h5ad('../data/processed/BoneMarrow/BoneMarrow2k_train.h5ad')
        test_data = sc.read_h5ad('../data/processed/BoneMarrow/BoneMarrow2k_test.h5ad')
        valid_data = sc.read_h5ad('../data/processed/BoneMarrow/BoneMarrow2k_validation.h5ad')
        cc_data = sc.read_h5ad(f'../results/{dataset}/Stage1_Gene1000_CC200000_TF10/GRouNdGAN_CC/simulated.h5ad')
    elif dataset == "LinearUniform":
        train_data = sc.read_h5ad('../data/processed/LinearUniform/LinearUniform5k_train.h5ad')
        test_data = sc.read_h5ad('../data/processed/LinearUniform/LinearUniform5k_test.h5ad')
        valid_data = sc.read_h5ad('../data/processed/LinearUniform/LinearUniform5k_validation.h5ad')
        cc_data = sc.read_h5ad(f'../results/{dataset}/Stage1_Gene100_CC200000_TF10/GRouNdGAN_CC/simulated.h5ad')
    else:
        break
    
    
    train_array = get_array(train_data)
    test_array = get_array(test_data)
    valid_array = get_array(valid_data)
    cc_array = get_array(cc_data)
    
    
    # if dataset in global_df_.dataset.unique():
    #     continue
    
    dist_df=compute_all_distances(test_array, cc_array)
    dist_df['tag'] = "Test vs Stage 1"
    dist_df['dataset'] = dataset
    dist_df["setting"] = setting
    global_df.append(dist_df)
    
    
    dist_df=compute_all_distances(train_array, cc_array)
    dist_df['tag'] = "Train vs Stage 1"
    dist_df['dataset'] = dataset
    dist_df["setting"] = setting
    global_df.append(dist_df)

# %%
for dataset in ["PBMC_CTL"]:

    print(f"*******{dataset}")
    if dataset == "PBMC":
        train_data = sc.read_h5ad('../data/processed/PBMC/PBMC68k_train.h5ad')
        test_data = sc.read_h5ad('../data/processed/PBMC/PBMC68k_test.h5ad')
        valid_data = sc.read_h5ad('../data/processed/PBMC/PBMC68k_validation.h5ad')
    elif dataset == "PBMC_CTL":
        train_data = sc.read_h5ad('../data/processed/PBMC_CTL/PBMC_CTL20k_train.h5ad')
        test_data = sc.read_h5ad('../data/processed/PBMC_CTL/PBMC_CTL20k_test.h5ad')
        valid_data = sc.read_h5ad('../data/processed/PBMC_CTL/PBMC_CTL20k_validation.h5ad')
    elif dataset == "BoneMarrow":
        train_data = sc.read_h5ad('../data/processed/BoneMarrow/BoneMarrow2k_train.h5ad')
        test_data = sc.read_h5ad('../data/processed/BoneMarrow/BoneMarrow2k_test.h5ad')
        valid_data = sc.read_h5ad('../data/processed/BoneMarrow/BoneMarrow2k_validation.h5ad')
    else:
        break
    
    tf10_data = sc.read_h5ad(f'../results/{dataset}/GRNBoost2/Gene1000_CC200000_TF10_seed1/GRouNdGAN/simulated_130k.h5ad')
    tf15_data = sc.read_h5ad(f'../results/{dataset}/GRNBoost2/Gene1000_CC200000_TF15_seed1/GRouNdGAN/simulated.h5ad')
    
    tf10_array = get_array(tf10_data)
    tf15_array = get_array(tf15_data)
    
    test_array = get_array(test_data)
    
    # if dataset in global_df_.dataset.unique():
    #     continue
    
    dist_df=compute_all_distances(test_array, tf10_array)
    dist_df['tag'] = "Test vs Stage 2 @130K"
    dist_df['dataset'] = dataset
    global_df.append(dist_df)
    
    dist_df=compute_all_distances(test_array, tf15_array)
    dist_df['tag'] = "Test vs Stage 2 @130K [TF15]"
    dist_df['dataset'] = dataset
    global_df.append(dist_df)

# %%
for dataset in ["PBMC_CTL"]:

    print(f"*******{dataset}")
    if dataset == "PBMC":
        train_data = sc.read_h5ad('../data/processed/PBMC/PBMC68k_train.h5ad')
        test_data = sc.read_h5ad('../data/processed/PBMC/PBMC68k_test.h5ad')
        valid_data = sc.read_h5ad('../data/processed/PBMC/PBMC68k_validation.h5ad')
    elif dataset == "PBMC_CTL":
        train_data = sc.read_h5ad('../data/processed/PBMC_CTL/PBMC_CTL20k_train.h5ad')
        test_data = sc.read_h5ad('../data/processed/PBMC_CTL/PBMC_CTL20k_test.h5ad')
        valid_data = sc.read_h5ad('../data/processed/PBMC_CTL/PBMC_CTL20k_validation.h5ad')
    elif dataset == "BoneMarrow":
        train_data = sc.read_h5ad('../data/processed/BoneMarrow/BoneMarrow2k_train.h5ad')
        test_data = sc.read_h5ad('../data/processed/BoneMarrow/BoneMarrow2k_test.h5ad')
        valid_data = sc.read_h5ad('../data/processed/BoneMarrow/BoneMarrow2k_validation.h5ad')
    else:
        break
    
    tf10_bottom_data = sc.read_h5ad(f'../results/{dataset}/GRNBoost2/Gene1000_CC200000_Bottom_TF10_seed1/GRouNdGAN/simulated.h5ad')
    tf10_bottom_array = get_array(tf10_bottom_data)
   
    
    test_array = get_array(test_data)
    
    
    # if dataset in global_df_.dataset.unique():
    #     continue
    
    dist_df=compute_all_distances(test_array, tf10_bottom_array)
    dist_df['tag'] = "Test vs Stage 2 [Bottom TF10]"
    dist_df['dataset'] = dataset
    global_df.append(dist_df)

# %%
setting="GRNB2"
# for dataset in ["PBMC", "BoneMarrow", "PBMC_CTL", "LinearUniform"]:
for dataset in ["LinearUniform"]:

    print(f"*******{dataset}")
    if dataset == "PBMC":
        train_data = sc.read_h5ad('../data/processed/PBMC/PBMC68k_train.h5ad')
        test_data = sc.read_h5ad('../data/processed/PBMC/PBMC68k_test.h5ad')
        valid_data = sc.read_h5ad('../data/processed/PBMC/PBMC68k_validation.h5ad')
        stage2_data = sc.read_h5ad(f'../results/{dataset}/GRNBoost2/Gene1000_CC200000_TF10_seed1/GRouNdGAN/simulated.h5ad')
    elif dataset == "PBMC_CTL":
        train_data = sc.read_h5ad('../data/processed/PBMC_CTL/PBMC_CTL20k_train.h5ad')
        test_data = sc.read_h5ad('../data/processed/PBMC_CTL/PBMC_CTL20k_test.h5ad')
        valid_data = sc.read_h5ad('../data/processed/PBMC_CTL/PBMC_CTL20k_validation.h5ad')
        stage2_data = sc.read_h5ad(f'../results/{dataset}/GRNBoost2/Gene1000_CC200000_TF10_seed1/GRouNdGAN/simulated.h5ad')
    elif dataset == "BoneMarrow":
        train_data = sc.read_h5ad('../data/processed/BoneMarrow/BoneMarrow2k_train.h5ad')
        test_data = sc.read_h5ad('../data/processed/BoneMarrow/BoneMarrow2k_test.h5ad')
        valid_data = sc.read_h5ad('../data/processed/BoneMarrow/BoneMarrow2k_validation.h5ad')
        stage2_data = sc.read_h5ad(f'../results/{dataset}/GRNBoost2/Gene1000_CC200000_TF10_seed1/GRouNdGAN/simulated.h5ad')
    elif dataset == "LinearUniform":
        train_data = sc.read_h5ad('../data/processed/LinearUniform/LinearUniform5k_train.h5ad')
        test_data = sc.read_h5ad('../data/processed/LinearUniform/LinearUniform5k_test.h5ad')
        valid_data = sc.read_h5ad('../data/processed/LinearUniform/LinearUniform5k_validation.h5ad')
        stage2_data = sc.read_h5ad(f'../results/{dataset}/Gene100_CC200000_TF10_seed1/GRouNdGAN/simulated.h5ad')
    else:
        break
    
    
    stage2_array = get_array(stage2_data)
   
    
    test_array = get_array(test_data)
    train_array = get_array(train_data)
    
    # if dataset in global_df_.dataset.unique():
    #     continue
    
    dist_df=compute_all_distances(test_array, stage2_array)
    dist_df['tag'] = "Test vs Stage 2"
    dist_df['dataset'] = dataset
    dist_df["setting"] = setting
    global_df.append(dist_df)
    
    dist_df=compute_all_distances(train_array, stage2_array)
    dist_df['tag'] = "Train vs Stage 2"
    dist_df['dataset'] = dataset
    dist_df["setting"] = setting
    global_df.append(dist_df)

# %%
global_df_ = pd.concat(global_df)
global_df_.groupby(['dataset', 'tag', 'setting']).mean()

# %%
print(global_df_.groupby(['dataset', 'tag']).mean()[[""]].round(5).to_latex())
